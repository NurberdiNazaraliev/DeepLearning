# %% [markdown]
# Data Collection and Processing Technologies
#
# ---
#
# # Introduction to TensorFlow
# ## Creating a small neural network
#
# ---

# %%
import tensorflow as tf
import numpy as np

# %%
# one input one output

weight = 0.5
y_real = 0.8
input = 0.9
alpha = 0.1

for iteration in range(20):
    pred = input * weight
    error = (pred - y_real) ** 2
    
    weight_delta = (pred - y_real) * input
    
    weight = weight - weight_delta * alpha
    print(f"Error: {round(error, 5)}| Weight: {round(weight, 5)} | Prediction: {round(pred, 5)}")
# Out:
# Error: 0.1225| Weight: 0.5315 | Prediction: 0.45
# Error: 0.10346| Weight: 0.56045 | Prediction: 0.47835
# Error: 0.08738| Weight: 0.58705 | Prediction: 0.5044
# Error: 0.0738| Weight: 0.6115 | Prediction: 0.52835
# Error: 0.06232| Weight: 0.63397 | Prediction: 0.55035
# Error: 0.05264| Weight: 0.65462 | Prediction: 0.57057
# Error: 0.04446| Weight: 0.67359 | Prediction: 0.58916
# Error: 0.03755| Weight: 0.69103 | Prediction: 0.60623
# Error: 0.03171| Weight: 0.70706 | Prediction: 0.62193
# Error: 0.02678| Weight: 0.72179 | Prediction: 0.63635
# Error: 0.02262| Weight: 0.73532 | Prediction: 0.64961
# Error: 0.0191| Weight: 0.74776 | Prediction: 0.66179
# Error: 0.01613| Weight: 0.75919 | Prediction: 0.67299
# Error: 0.01363| Weight: 0.7697 | Prediction: 0.68327
# Error: 0.01151| Weight: 0.77935 | Prediction: 0.69273
# Error: 0.00972| Weight: 0.78822 | Prediction: 0.70142
# Error: 0.00821| Weight: 0.79638 | Prediction: 0.7094
# Error: 0.00693| Weight: 0.80387 | Prediction: 0.71674
# Error: 0.00585| Weight: 0.81076 | Prediction: 0.72348
# Error: 0.00494| Weight: 0.81709 | Prediction: 0.72968

# %%
input_var = tf.Variable(initial_value = 3.0)

# y = x^2
# f'(x) = 2x

with tf.GradientTape() as tape:
    result = input_var ** 2
    
gradient = tape.gradient(result, input_var) # gradient(y, x)
print(gradient)
# Out:
# tf.Tensor(6.0, shape=(), dtype=float32)

# %%
# one input one output
weight = tf.Variable(initial_value= 0.5)
y_real = 0.8
input = 0.9
alpha = 0.1

for iteration in range(20):
    
    with tf.GradientTape() as tape:
        pred = input * weight
        error = (pred - y_real) ** 2
    
    
    weight_delta = tape.gradient(error, weight)
    print('w is', weight_delta)
    
    weight.assign_sub(alpha*weight_delta)
    print(f"Error: {round(float(error), 5)} | Weight: {round(float(weight), 5)} | Prediction: {round(float(pred), 5)}")
# Out:
# w is tf.Tensor(-0.63000005, shape=(), dtype=float32)
# Error: 0.1225 | Weight: 0.563 | Prediction: 0.45
# w is tf.Tensor(-0.52794003, shape=(), dtype=float32)
# Error: 0.08602 | Weight: 0.61579 | Prediction: 0.5067
# w is tf.Tensor(-0.44241375, shape=(), dtype=float32)
# Error: 0.06041 | Weight: 0.66004 | Prediction: 0.55421
# w is tf.Tensor(-0.37074274, shape=(), dtype=float32)
# Error: 0.04242 | Weight: 0.69711 | Prediction: 0.59403
# w is tf.Tensor(-0.31068242, shape=(), dtype=float32)
# Error: 0.02979 | Weight: 0.72818 | Prediction: 0.6274
# w is tf.Tensor(-0.26035184, shape=(), dtype=float32)
# Error: 0.02092 | Weight: 0.75421 | Prediction: 0.65536
# w is tf.Tensor(-0.21817484, shape=(), dtype=float32)
# Error: 0.01469 | Weight: 0.77603 | Prediction: 0.67879
# w is tf.Tensor(-0.18283051, shape=(), dtype=float32)
# Error: 0.01032 | Weight: 0.79431 | Prediction: 0.69843
# w is tf.Tensor(-0.15321197, shape=(), dtype=float32)
# Error: 0.00725 | Weight: 0.80963 | Prediction: 0.71488
# w is tf.Tensor(-0.12839155, shape=(), dtype=float32)
# Error: 0.00509 | Weight: 0.82247 | Prediction: 0.72867
# w is tf.Tensor(-0.107592195, shape=(), dtype=float32)
# Error: 0.00357 | Weight: 0.83323 | Prediction: 0.74023
# w is tf.Tensor(-0.09016224, shape=(), dtype=float32)
# Error: 0.00251 | Weight: 0.84225 | Prediction: 0.74991
# w is tf.Tensor(-0.0755559, shape=(), dtype=float32)
# Error: 0.00176 | Weight: 0.84981 | Prediction: 0.75802
# w is tf.Tensor(-0.063315906, shape=(), dtype=float32)
# Error: 0.00124 | Weight: 0.85614 | Prediction: 0.76482
# w is tf.Tensor(-0.053058706, shape=(), dtype=float32)
# Error: 0.00087 | Weight: 0.86144 | Prediction: 0.77052
# w is tf.Tensor(-0.04446319, shape=(), dtype=float32)
# Error: 0.00061 | Weight: 0.86589 | Prediction: 0.7753
# w is tf.Tensor(-0.037260175, shape=(), dtype=float32)
# Error: 0.00043 | Weight: 0.86961 | Prediction: 0.7793
# w is tf.Tensor(-0.031224024, shape=(), dtype=float32)
# Error: 0.0003 | Weight: 0.87274 | Prediction: 0.78265
# w is tf.Tensor(-0.0261657, shape=(), dtype=float32)
# Error: 0.00021 | Weight: 0.87535 | Prediction: 0.78546
# w is tf.Tensor(-0.021926843, shape=(), dtype=float32)
# Error: 0.00015 | Weight: 0.87755 | Prediction: 0.78782

# %% [markdown]
# ### Multiple inputs and outputs

# %%
def neural_network(input, weights):
    prediction = input.dot(weights.T)
    return prediction

def outer_prod(vec1, vec2):
    out = np.zeros((len(vec1), len(vec2)))
    
    for i in range(len(vec1)):
        for j in range(len(vec2)):
            out[i][j] = vec1[i] * vec2[j]
    return out

# %%
weights = np.zeros((3, 3))

input = np.array([8.5, 0.65, 1.2])
y_real = [0.1, 1, 0.1]

error = [0, 0, 0]
delta = [0, 0, 0]
alpha = 0.01


for iter in range(16):
    pred = neural_network(input, weights)

    for i in range(len(y_real)):
        error[i] = (pred[i] - y_real[i]) ** 2
        delta[i] = pred[i] - y_real[i]

    weight_deltas = outer_prod(delta, input)

    for i in range(len(weights)):
        for j in range(len(weights[0])):
            weights[i][j] -= alpha * weight_deltas[i][j]
    
    print("Iteration: " + str(iter))
    print("Prediction: " + str(pred))
    print("---")
# Out:
# Iteration: 0
# Prediction: [0. 0. 0.]
# ---
# Iteration: 1
# Prediction: [0.0741125 0.741125  0.0741125]
# ---
# Iteration: 2
# Prediction: [0.09329837 0.93298373 0.09329837]
# ---
# Iteration: 3
# Prediction: [0.09826512 0.98265116 0.09826512]
# ---
# Iteration: 4
# Prediction: [0.09955088 0.99550882 0.09955088]
# ---
# Iteration: 5
# Prediction: [0.09988373 0.99883735 0.09988373]
# ---
# Iteration: 6
# Prediction: [0.0999699  0.99969902 0.0999699 ]
# ---
# Iteration: 7
# Prediction: [0.09999221 0.99992208 0.09999221]
# ---
# Iteration: 8
# Prediction: [0.09999798 0.99997983 0.09999798]
# ---
# Iteration: 9
# Prediction: [0.09999948 0.99999478 0.09999948]
# ---
# Iteration: 10
# Prediction: [0.09999986 0.99999865 0.09999986]
# ---
# Iteration: 11
# Prediction: [0.09999997 0.99999965 0.09999997]
# ---
# Iteration: 12
# Prediction: [0.09999999 0.99999991 0.09999999]
# ---
# Iteration: 13
# Prediction: [0.1        0.99999998 0.1       ]
# ---
# Iteration: 14
# Prediction: [0.1        0.99999999 0.1       ]
# ---
# Iteration: 15
# Prediction: [0.1 1.  0.1]
# ---

# %% [markdown]
# ### Implement the above algorithm with TensorFlow

# %%
weights = tf.Variable(initial_value = tf.zeros((1,3)))
input = tf.Variable(initial_value = tf.constant([8.5, 0.65, 1.2], shape=[1, 3]))
y_real = tf.Variable(initial_value = tf.constant([0.1, 1, 0.1], shape=[1, 3]))
error =  tf.Variable(initial_value = tf.constant([0, 0, 0], shape=[1, 3]))
weight_deltas= tf.Variable(initial_value = tf.zeros((1,3)))
alpha = 0.01


for iter in range(200):
    with tf.GradientTape() as tape:
        pred = input * weights
        error = (pred - y_real) ** 2    

        
    weight_deltas = tape.gradient(error, weights)

    weights.assign_sub(alpha*weight_deltas)

    
    print("Iteration: " + str(iter))
    print("Prediction: " + str(pred))
    print("---")
# Out:
# Iteration: 0
# Prediction: tf.Tensor([[0. 0. 0.]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 1
# Prediction: tf.Tensor([[0.1445  0.00845 0.00288]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 2
# Prediction: tf.Tensor([[0.08019751 0.0168286  0.00567706]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 3
# Prediction: tf.Tensor([[0.10881212 0.02513639 0.00839356]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 4
# Prediction: tf.Tensor([[0.09607861 0.03337399 0.01103182]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 5
# Prediction: tf.Tensor([[0.10174502 0.04154198 0.01359411]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 6
# Prediction: tf.Tensor([[0.09922347 0.04964095 0.0160826 ]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 7
# Prediction: tf.Tensor([[0.10034556 0.05767148 0.01849942]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 8
# Prediction: tf.Tensor([[0.09984623 0.06563415 0.02084664]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 9
# Prediction: tf.Tensor([[0.10006843 0.07352954 0.02312625]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 10
# Prediction: tf.Tensor([[0.09996956 0.08135822 0.02534022]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 11
# Prediction: tf.Tensor([[0.10001355 0.08912074 0.02749042]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 12
# Prediction: tf.Tensor([[0.09999397 0.09681766 0.02957869]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 13
# Prediction: tf.Tensor([[0.10000268 0.10444956 0.03160683]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 14
# Prediction: tf.Tensor([[0.09999881 0.11201696 0.03357655]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 15
# Prediction: tf.Tensor([[0.10000053 0.11952042 0.03548955]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 16
# Prediction: tf.Tensor([[0.09999976 0.12696047 0.03734745]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 17
# Prediction: tf.Tensor([[0.10000011 0.13433765 0.03915184]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 18
# Prediction: tf.Tensor([[0.09999996 0.14165251 0.04090427]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 19
# Prediction: tf.Tensor([[0.10000002 0.14890553 0.04260623]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 20
# Prediction: tf.Tensor([[0.09999999 0.15609728 0.04425917]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 21
# Prediction: tf.Tensor([[0.1        0.16322826 0.04586451]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 22
# Prediction: tf.Tensor([[0.1        0.17029898 0.04742361]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 23
# Prediction: tf.Tensor([[0.1        0.17730996 0.04893781]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 24
# Prediction: tf.Tensor([[0.1       0.1842617 0.0504084]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 25
# Prediction: tf.Tensor([[0.1        0.19115467 0.05183664]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 26
# Prediction: tf.Tensor([[0.1        0.19798942 0.05322374]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 27
# Prediction: tf.Tensor([[0.1       0.2047664 0.0545709]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 28
# Prediction: tf.Tensor([[0.1        0.21148612 0.05587926]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 29
# Prediction: tf.Tensor([[0.1        0.21814907 0.05714994]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 30
# Prediction: tf.Tensor([[0.1        0.2247557  0.05838402]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 31
# Prediction: tf.Tensor([[0.1        0.23130651 0.05958256]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 32
# Prediction: tf.Tensor([[0.1        0.23780197 0.06074658]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 33
# Prediction: tf.Tensor([[0.1        0.24424255 0.06187708]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 34
# Prediction: tf.Tensor([[0.1        0.2506287  0.06297502]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 35
# Prediction: tf.Tensor([[0.1        0.25696087 0.06404134]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 36
# Prediction: tf.Tensor([[0.1        0.26323956 0.06507695]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 37
# Prediction: tf.Tensor([[0.1        0.26946518 0.06608273]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 38
# Prediction: tf.Tensor([[0.1        0.2756382  0.06705955]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 39
# Prediction: tf.Tensor([[0.1        0.28175905 0.06800823]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 40
# Prediction: tf.Tensor([[0.1        0.28782818 0.06892959]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 41
# Prediction: tf.Tensor([[0.1        0.29384604 0.06982442]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 42
# Prediction: tf.Tensor([[0.1        0.29981303 0.07069348]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 43
# Prediction: tf.Tensor([[0.1        0.30572963 0.07153751]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 44
# Prediction: tf.Tensor([[0.1        0.3115962  0.07235723]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 45
# Prediction: tf.Tensor([[0.1        0.3174132  0.07315334]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 46
# Prediction: tf.Tensor([[0.1        0.3231811  0.07392652]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 47
# Prediction: tf.Tensor([[0.1        0.32890022 0.07467744]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 48
# Prediction: tf.Tensor([[0.1        0.33457097 0.07540672]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 49
# Prediction: tf.Tensor([[0.1        0.34019387 0.07611501]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 50
# Prediction: tf.Tensor([[0.1        0.34576923 0.0768029 ]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 51
# Prediction: tf.Tensor([[0.1        0.35129747 0.07747098]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 52
# Prediction: tf.Tensor([[0.1        0.35677898 0.07811981]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 53
# Prediction: tf.Tensor([[0.1        0.3622142  0.07874996]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 54
# Prediction: tf.Tensor([[0.1        0.3676035  0.07936196]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 55
# Prediction: tf.Tensor([[0.1        0.37294728 0.07995634]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 56
# Prediction: tf.Tensor([[0.1        0.37824586 0.08053359]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 57
# Prediction: tf.Tensor([[0.1        0.3834997  0.08109424]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 58
# Prediction: tf.Tensor([[0.1        0.38870913 0.08163872]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 59
# Prediction: tf.Tensor([[0.1        0.39387453 0.08216753]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 60
# Prediction: tf.Tensor([[0.1       0.3989963 0.0826811]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 61
# Prediction: tf.Tensor([[0.1        0.40407476 0.08317988]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 62
# Prediction: tf.Tensor([[0.1        0.40911034 0.0836643 ]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 63
# Prediction: tf.Tensor([[0.1        0.41410336 0.08413476]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 64
# Prediction: tf.Tensor([[0.1        0.41905415 0.08459169]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 65
# Prediction: tf.Tensor([[0.1        0.42396313 0.08503545]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 66
# Prediction: tf.Tensor([[0.1        0.42883065 0.08546643]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 67
# Prediction: tf.Tensor([[0.1        0.43365702 0.085885  ]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 68
# Prediction: tf.Tensor([[0.1        0.43844265 0.08629151]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 69
# Prediction: tf.Tensor([[0.1        0.4431878  0.08668631]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 70
# Prediction: tf.Tensor([[0.1        0.44789287 0.08706975]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 71
# Prediction: tf.Tensor([[0.1        0.4525582  0.08744214]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 72
# Prediction: tf.Tensor([[0.1        0.45718408 0.0878038 ]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 73
# Prediction: tf.Tensor([[0.1        0.46177086 0.08815506]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 74
# Prediction: tf.Tensor([[0.1        0.4663189  0.08849619]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 75
# Prediction: tf.Tensor([[0.1       0.4708285 0.0888275]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 76
# Prediction: tf.Tensor([[0.1        0.4753     0.08914927]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 77
# Prediction: tf.Tensor([[0.1        0.4797337  0.08946177]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 78
# Prediction: tf.Tensor([[0.1        0.48412997 0.08976527]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 79
# Prediction: tf.Tensor([[0.1        0.48848906 0.09006003]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 80
# Prediction: tf.Tensor([[0.1       0.4928113 0.0903463]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 81
# Prediction: tf.Tensor([[0.1        0.49709705 0.09062432]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 82
# Prediction: tf.Tensor([[0.1        0.5013466  0.09089434]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 83
# Prediction: tf.Tensor([[0.1        0.5055602  0.09115659]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 84
# Prediction: tf.Tensor([[0.1        0.5097382  0.09141128]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 85
# Prediction: tf.Tensor([[0.1        0.5138809  0.09165863]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 86
# Prediction: tf.Tensor([[0.1        0.5179886  0.09189886]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 87
# Prediction: tf.Tensor([[0.1        0.52206165 0.09213217]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 88
# Prediction: tf.Tensor([[0.1        0.5261002  0.09235877]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 89
# Prediction: tf.Tensor([[0.1        0.53010464 0.09257884]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 90
# Prediction: tf.Tensor([[0.1        0.53407526 0.09279256]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 91
# Prediction: tf.Tensor([[0.1        0.5380123  0.09300014]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 92
# Prediction: tf.Tensor([[0.1        0.5419161  0.09320173]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 93
# Prediction: tf.Tensor([[0.1        0.5457869  0.09339753]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 94
# Prediction: tf.Tensor([[0.1        0.54962504 0.09358767]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 95
# Prediction: tf.Tensor([[0.1        0.5534307  0.09377236]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 96
# Prediction: tf.Tensor([[0.1        0.5572042  0.09395172]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 97
# Prediction: tf.Tensor([[0.1       0.5609458 0.0941259]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 98
# Prediction: tf.Tensor([[0.1        0.5646558  0.09429508]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 99
# Prediction: tf.Tensor([[0.1        0.5683344  0.09445938]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 100
# Prediction: tf.Tensor([[0.1        0.571982   0.09461896]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 101
# Prediction: tf.Tensor([[0.1        0.5755987  0.09477394]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 102
# Prediction: tf.Tensor([[0.1        0.57918495 0.09492444]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 103
# Prediction: tf.Tensor([[0.1        0.58274084 0.09507062]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 104
# Prediction: tf.Tensor([[0.1        0.58626664 0.09521259]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 105
# Prediction: tf.Tensor([[0.1        0.58976275 0.09535047]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 106
# Prediction: tf.Tensor([[0.1        0.59322923 0.09548438]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 107
# Prediction: tf.Tensor([[0.1        0.5966664  0.09561443]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 108
# Prediction: tf.Tensor([[0.1        0.6000746  0.09574073]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 109
# Prediction: tf.Tensor([[0.1        0.60345393 0.09586339]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 110
# Prediction: tf.Tensor([[0.1        0.6068048  0.09598253]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 111
# Prediction: tf.Tensor([[0.1        0.6101273  0.09609824]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 112
# Prediction: tf.Tensor([[0.1       0.6134217 0.0962106]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 113
# Prediction: tf.Tensor([[0.1        0.61668825 0.09631974]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 114
# Prediction: tf.Tensor([[0.1        0.6199273  0.09642573]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 115
# Prediction: tf.Tensor([[0.1        0.62313884 0.09652867]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 116
# Prediction: tf.Tensor([[0.1        0.62632334 0.09662865]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 117
# Prediction: tf.Tensor([[0.1        0.6294809  0.09672575]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 118
# Prediction: tf.Tensor([[0.1        0.6326118  0.09682004]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 119
# Prediction: tf.Tensor([[0.1        0.63571626 0.09691162]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 120
# Prediction: tf.Tensor([[0.1        0.6387944  0.09700056]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 121
# Prediction: tf.Tensor([[0.1        0.6418466  0.09708695]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 122
# Prediction: tf.Tensor([[0.1        0.644873   0.09717085]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 123
# Prediction: tf.Tensor([[0.1        0.6478739  0.09725232]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 124
# Prediction: tf.Tensor([[0.1        0.6508494  0.09733146]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 125
# Prediction: tf.Tensor([[0.1        0.6537997  0.09740832]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 126
# Prediction: tf.Tensor([[0.1        0.65672517 0.09748295]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 127
# Prediction: tf.Tensor([[0.1        0.6596258  0.09755544]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 128
# Prediction: tf.Tensor([[0.1        0.66250193 0.09762584]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 129
# Prediction: tf.Tensor([[0.1        0.66535383 0.09769422]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 130
# Prediction: tf.Tensor([[0.1        0.6681816  0.09776063]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 131
# Prediction: tf.Tensor([[0.1        0.67098546 0.09782512]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 132
# Prediction: tf.Tensor([[0.1        0.67376566 0.09788776]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 133
# Prediction: tf.Tensor([[0.1        0.67652225 0.09794859]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 134
# Prediction: tf.Tensor([[0.1        0.67925566 0.09800767]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 135
# Prediction: tf.Tensor([[0.1        0.681966   0.09806506]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 136
# Prediction: tf.Tensor([[0.1        0.68465334 0.09812078]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 137
# Prediction: tf.Tensor([[0.1       0.687318  0.0981749]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 138
# Prediction: tf.Tensor([[0.1        0.68996024 0.09822746]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 139
# Prediction: tf.Tensor([[0.1        0.69258004 0.09827852]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 140
# Prediction: tf.Tensor([[0.1        0.69517773 0.09832809]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 141
# Prediction: tf.Tensor([[0.1        0.6977534  0.09837624]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 142
# Prediction: tf.Tensor([[0.1       0.7003075 0.098423 ]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 143
# Prediction: tf.Tensor([[0.1        0.70283985 0.09846842]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 144
# Prediction: tf.Tensor([[0.1        0.7053509  0.09851254]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 145
# Prediction: tf.Tensor([[0.1        0.7078407  0.09855537]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 146
# Prediction: tf.Tensor([[0.1        0.71030945 0.09859697]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 147
# Prediction: tf.Tensor([[0.1        0.7127573  0.09863737]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 148
# Prediction: tf.Tensor([[0.1        0.7151845  0.09867661]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 149
# Prediction: tf.Tensor([[0.1        0.7175912  0.09871473]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 150
# Prediction: tf.Tensor([[0.1        0.71997756 0.09875175]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 151
# Prediction: tf.Tensor([[0.1        0.72234374 0.0987877 ]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 152
# Prediction: tf.Tensor([[0.1        0.7246899  0.09882261]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 153
# Prediction: tf.Tensor([[0.1        0.72701627 0.09885652]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 154
# Prediction: tf.Tensor([[0.1        0.72932297 0.09888945]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 155
# Prediction: tf.Tensor([[0.1        0.7316102  0.09892143]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 156
# Prediction: tf.Tensor([[0.1        0.7338781  0.09895249]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 157
# Prediction: tf.Tensor([[0.1        0.7361268  0.09898265]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 158
# Prediction: tf.Tensor([[0.1        0.73835653 0.09901195]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 159
# Prediction: tf.Tensor([[0.1        0.74056745 0.09904041]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 160
# Prediction: tf.Tensor([[0.1        0.74275964 0.09906805]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 161
# Prediction: tf.Tensor([[0.1        0.74493337 0.09909489]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 162
# Prediction: tf.Tensor([[0.1        0.74708873 0.09912096]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 163
# Prediction: tf.Tensor([[0.1        0.7492258  0.09914628]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 164
# Prediction: tf.Tensor([[0.1        0.7513448  0.09917086]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 165
# Prediction: tf.Tensor([[0.1        0.7534459  0.09919474]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 166
# Prediction: tf.Tensor([[0.1        0.7555293  0.09921794]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 167
# Prediction: tf.Tensor([[0.1        0.75759506 0.09924046]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 168
# Prediction: tf.Tensor([[0.1        0.75964344 0.09926233]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 169
# Prediction: tf.Tensor([[0.1        0.7616744  0.09928358]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 170
# Prediction: tf.Tensor([[0.1        0.76368827 0.09930421]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 171
# Prediction: tf.Tensor([[0.1        0.7656851  0.09932425]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 172
# Prediction: tf.Tensor([[0.1        0.767665   0.09934372]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 173
# Prediction: tf.Tensor([[0.1        0.7696283  0.09936262]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 174
# Prediction: tf.Tensor([[0.1        0.77157485 0.09938097]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 175
# Prediction: tf.Tensor([[0.1        0.77350503 0.0993988 ]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 176
# Prediction: tf.Tensor([[0.1        0.77541894 0.09941611]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 177
# Prediction: tf.Tensor([[0.1        0.7773167  0.09943294]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 178
# Prediction: tf.Tensor([[0.1        0.77919835 0.09944927]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 179
# Prediction: tf.Tensor([[0.1        0.7810641  0.09946513]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 180
# Prediction: tf.Tensor([[0.1        0.7829141  0.09948053]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 181
# Prediction: tf.Tensor([[0.1        0.7847485  0.09949549]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 182
# Prediction: tf.Tensor([[0.1        0.7865674  0.09951002]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 183
# Prediction: tf.Tensor([[0.1        0.7883709  0.09952413]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 184
# Prediction: tf.Tensor([[0.1        0.7901592  0.09953783]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 185
# Prediction: tf.Tensor([[0.1        0.7919324  0.09955115]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 186
# Prediction: tf.Tensor([[0.1        0.79369056 0.09956408]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 187
# Prediction: tf.Tensor([[0.1        0.7954338  0.09957663]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 188
# Prediction: tf.Tensor([[0.1        0.7971624  0.09958883]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 189
# Prediction: tf.Tensor([[0.1        0.7988764  0.09960067]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 190
# Prediction: tf.Tensor([[0.1        0.80057585 0.09961216]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 191
# Prediction: tf.Tensor([[0.1        0.80226105 0.09962333]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 192
# Prediction: tf.Tensor([[0.1        0.80393195 0.09963417]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 193
# Prediction: tf.Tensor([[0.1        0.8055888  0.09964471]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 194
# Prediction: tf.Tensor([[0.1        0.80723155 0.09965494]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 195
# Prediction: tf.Tensor([[0.1        0.8088605  0.09966487]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 196
# Prediction: tf.Tensor([[0.1        0.8104756  0.09967453]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 197
# Prediction: tf.Tensor([[0.1        0.81207705 0.0996839 ]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 198
# Prediction: tf.Tensor([[0.1      0.813665 0.099693]], shape=(1, 3), dtype=float32)
# ---
# Iteration: 199
# Prediction: tf.Tensor([[0.1        0.8152395  0.09970184]], shape=(1, 3), dtype=float32)
# ---

# %%
0.1445*0.009435
# Out:
# 0.0013633575
