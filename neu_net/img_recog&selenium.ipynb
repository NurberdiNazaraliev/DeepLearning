# %%
import cv2 as cv
import os
import numpy as np
import cv2

# %%
from selenium import webdriver
username = "nazaraliev_ai"
password = "asdfasd3"
url = "https://ecourse.auca.kg/login/index.php"
username1 = "nazaraliev_n@auca.kg"
password1 = "091207253613nbN"
url1 = "https://portal.edupage.org/"

# %%
driver = webdriver.Chrome("C:/Users/nurbe/OneDrive/Desktop/proj/chromedriver.exe")
# Out:
# C:\Users\nurbe\AppData\Local\Temp/ipykernel_15232/3496870245.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("C:/Users/nurbe/OneDrive/Desktop/proj/chromedriver.exe")

# %%
import cv2
vidcap = cv2.VideoCapture('narek_vid.mp4')
success,image = vidcap.read()
count = 0
if not os.path.exists("video_convert/train/narek"):
    os.makedirs("video_convert/train/narek")
while success:
  cv2.imwrite("video_convert/train/narek/frame%d.jpg" % count, image)     # save frame as JPEG file      
  success,image = vidcap.read()
  print('Read a new frame: ', success)
  count += 1
# Out:
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# ...

# %%
import cv2
vidcap = cv2.VideoCapture('aibek_vid.mp4')
success,image = vidcap.read()
count = 0
if not os.path.exists("video_convert/train/aibek"):
    os.makedirs("video_convert/train/aibek")
while success:
  cv2.imwrite("video_convert/train/aibek/frame%d.jpg" % count, image)     # save frame as JPEG file      
  success,image = vidcap.read()
  print('Read a new frame: ', success)
  count += 1
# Out:
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# ...

# %%
test_labels=[]

# %%
people = ['narek', 'aibek']

# direction to the folder with images
DIR = r'video_convert\train'

haar = cv.CascadeClassifier('haar.xml')

features = []
labels = []

def create_train():
    for person in people:
        path = os.path.join(DIR, person)
        label = people.index(person)

        for img in os.listdir(path):
            img_path = os.path.join(path, img)

            img_array = cv.imread(img_path)
            gray = cv.cvtColor(img_array, cv.COLOR_BGR2GRAY)

            faces_rect = haar.detectMultiScale(gray)

            for (x, y, w, h) in faces_rect:
                faces_roi = gray[y:y+h, x:x+w]
                features.append(faces_roi)
                labels.append(label)

# %%
create_train()

print('НАТРЕНИРОВАНО! ---------------')

features = np.array(features, dtype='object')
labels = np.array(labels)

face_recognizer = cv.face.LBPHFaceRecognizer_create()

# Train the Recognizer on the features list and the labels list
face_recognizer.train(features,labels)

face_recognizer.save('face_trained.yml')
np.save('features.npy', features)
np.save('labels.npy', labels)
# Out:
# НАТРЕНИРОВАНО! ---------------

# %%
haar_cascade = cv.CascadeClassifier('haar.xml')

people = ['narek', 'aibek']
# features = np.load('features.npy', allow_pickle=True)
# labels = np.load('labels.npy')

face_recognizer = cv.face.LBPHFaceRecognizer_create()
face_recognizer.read('face_trained.yml')

img = cv.imread(r'video_convert/test/3.jpg')

gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)



# Detect the face in the image
faces_rect = haar_cascade.detectMultiScale(gray)

for (x,y,w,h) in faces_rect:
    faces_roi = gray[y:y+h,x:x+w]

    label, confidence = face_recognizer.predict(faces_roi)
    print(f'Label = {people[label]} with a confidence of {confidence}')
    test_labels.append(label)
    
    
    

    cv.putText(img, str(people[label]), (20,20), cv.FONT_HERSHEY_COMPLEX, 1.0, (0,255,0), thickness=2)
    cv.rectangle(img, (x,y), (x+w,y+h), (0,255,0), thickness=2)

if test_labels[0]==1:
    driver.get(url)
    driver.find_element_by_name("username").send_keys(username)
    driver.find_element_by_name("password").send_keys(password)
    driver.find_element_by_id("loginbtn").click()
if test_labels[0]==0:
    driver.get(url1)
    driver.find_element_by_name("meno").send_keys(username1)
    driver.find_element_by_name("heslo").send_keys(password1)
    driver.find_element_by_css_selector("input[type=\"submit\" i]").click()
    driver.find_element_by_class_name("edubarSmartLink ").click()
# Out:
# Label = narek with a confidence of 36.185688452939154
# C:\Users\nurbe\AppData\Local\Temp/ipykernel_15232/349223281.py:39: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   driver.find_element_by_name("meno").send_keys(username1)
# C:\Users\nurbe\AppData\Local\Temp/ipykernel_15232/349223281.py:40: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   driver.find_element_by_name("heslo").send_keys(password1)
# C:\Users\nurbe\AppData\Local\Temp/ipykernel_15232/349223281.py:41: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   driver.find_element_by_css_selector("input[type=\"submit\" i]").click()
# ...
