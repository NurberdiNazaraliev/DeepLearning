# %% [markdown]
# ---
#
# # Final Exam 2
# SEST19

# %% [markdown]
# #### Policy Statement on Cheating
#
# The cheating policy of this class will follow the policy of the college. Students are expected to know and comply with this policy. Cheating in this class includes: among the obvious, copying another person’s project or Individual work (in whole or in part), being caught talking during an exam/quiz. Since the person who assists in cheating is just as guilty as the person who is caught cheating – if two projects or individual works handed in are found to be the same, both students will be guilty of cheating. If a student is caught cheating on a quiz - the student will receive 0% on that quiz.
#
# !!!
# **If a student is caught cheating on an exam - the student will receive a 0% for that exam.**
# !!!
#
# Repeated case of plagiarism will result in automatic failure of the course. If the student is caught a third time, the student's expulsion from the university follows.
#
# NB: Plagiarism is a very serious question in the academic environment. The general rule to prevent plagiarism is to never pass off someone else's work as your own. Students are required to maintain high ethical standards when studying.
#
# ---

# %% [markdown]
# # Part 1. Quiz (5 p.)

# %% [markdown]
# #### 1. There are main stages of the Data Analysis. Arrange them in the correct order:
# Data Cleaning, Data Collection, Data Analylis, Interpreting the Results

# %% [markdown]
# # write your answer:
# 1. Data Collection
# 2. Data Cleaning
# 3. Data Analylis
# 4. Interpreting the Results

# %% [markdown]
# #### 2. There are images with 25 by 25 pixels resolution (color image). What should be the size of the input?
# * a. (625, )
# * b. (25, 25, 4)
# * c. (625, 3)

# %%
# write your answer:
# C

# %% [markdown]
# #### 3. Choose the right answer:
# * a. Keras is a high-level neural network library that runs on top of TensorFlow
# * b. Tensorflow is a high-level neural network library that runs on top of Keras
# * c. NumPy is a high-level neural network library that runs on top of TensorFlow

# %%
# write your answer:
# A

# %% [markdown]
# #### 4. Which of the given codes will create a rank-2 tensor?
# * a. `x = np.array([1, 2, 3])`
# * b. `x = np.array([[1, 2, 3], [4, 5, 6]])`
# * c. `x = np.array([1])`

# %%
# write your answer:
# b

# %% [markdown]
# #### 5. Training of the neural network model is:
# * a. adjusting the neural network weights
# * b. adjusting the number of neurons and layers
# * c. search for the best image

# %%
# write your answer:
# A

# %% [markdown]
# ---
# # Part 2. Neural Networks.

# %% [markdown]
# ## 1. Densely Connected Model (5 p.)
#
# 1.1. Below are the input and output data. How many inputs and outputs should there be?
# Implement and train a simple neural network using the NumPy. (3 p.)
#
# You can use the Keras, but not Tensorflow.

# %%
import numpy as np

# %%
input = np.array([5.5, 5.65, 3.2, 5.7, 7.5])
y_real = [0.8, 0.2]
weights = np.zeros((len(y_real), len(input)))
error = [0, 0]
delta = [0, 0]
alpha = 0.01

# your solution
def neural_network(input, weights):
    prediction = input.dot(weights.T)
    return prediction

def outer_prod(delta, input):
    out = np.zeros((len(delta), len(input)))
    for i in range(len(delta)):
        for j in range(len(input)):
            out[i][j] = input[j] * delta[i]
    return out

for iter in range(20):
   
    pred = neural_network(input, weights)
    for i in range(len(y_real)):
        error[i] = (pred[i] - y_real[i]) ** 2
        delta[i] =  pred[i] - y_real[i]

    weight_deltas = outer_prod(delta, input)
   
    weights = weights - (weight_deltas*alpha)
   
   
           
   
    # from each weight substract -> (alpha * weight_deltas[i][j])
    # write here the algorithm
   
    print("Iteration: " + str(iter))
    print("Prediction: " + str(pred))
    print("---")
# Out:
# Iteration: 0
# Prediction: [0. 0.]
# ---
# Iteration: 1
# Prediction: [1.28922  0.322305]
# ---
# Iteration: 2
# Prediction: [0.50082974 0.12520743]
# ---
# Iteration: 3
# Prediction: [0.98295009 0.24573752]
# ---
# Iteration: 4
# Prediction: [0.68812144 0.17203036]
# ---
# Iteration: 5
# Prediction: [0.86841653 0.21710413]
# ---
# Iteration: 6
# Prediction: [0.75816158 0.18954039]
# ---
# Iteration: 7
# Prediction: [0.82558524 0.20639631]
# ---
# Iteration: 8
# Prediction: [0.78435399 0.1960885 ]
# ---
# Iteration: 9
# Prediction: [0.80956793 0.20239198]
# ---
# Iteration: 10
# Prediction: [0.79414897 0.19853724]
# ---
# Iteration: 11
# Prediction: [0.80357805 0.20089451]
# ---
# Iteration: 12
# Prediction: [0.79781193 0.19945298]
# ---
# Iteration: 13
# Prediction: [0.80133806 0.20033451]
# ---
# Iteration: 14
# Prediction: [0.79918174 0.19979544]
# ---
# Iteration: 15
# Prediction: [0.80050038 0.2001251 ]
# ---
# Iteration: 16
# Prediction: [0.799694  0.1999235]
# ---
# ...

# %% [markdown]
# 1.2. Answer to the given questions:
#
# * How many iterations does the network take to train? (1 p.)

# %%
##19 itterations

# %% [markdown]
# * What should be the alpha coefficient? (1 p.)

# %%
## alpha == 0.01

# %% [markdown]
# ## 2. Convolutional Neural Networks (5 p.)
#
# Show 5 images in the attachment. Use the specified model to classify them.
# Show the results.

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
import os
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array

# %%
# EfficientNetV2S
model = tf.keras.applications.EfficientNetV2S()

# %%
def classify(model, img_path, target_size):
    img = image.load_img(img_path, target_size = target_size)
    img_array = image.img_to_array(img)

    img_batch = np.expand_dims(img_array, axis=0)

    img_preprocessed = preprocess_input(img_batch)
    
    prediction = model.predict(img_preprocessed)
    plt.imshow(img);
    plt.show();

    return decode_predictions(prediction, top=3)[0]

# %%
for i in range(1,5):
    img_path = f"attachments/2/{i}.jpg"
    target_size=(384, 384)
    prediction = classify(model, img_path, target_size)

    print(prediction)
# Out:
# [('n02690373', 'airliner', 0.86736083), ('n04592741', 'wing', 0.036809664), ('n04552348', 'warplane', 0.009234897)]
# [('n04332243', 'strainer', 0.4687843), ('n04270147', 'spatula', 0.35254294), ('n12144580', 'corn', 0.015871894)]
# [('n04589890', 'window_screen', 0.12286945), ('n04275548', 'spider_web', 0.08731905), ('n02708093', 'analog_clock', 0.05157286)]
# [('n04589890', 'window_screen', 0.35496092), ('n04332243', 'strainer', 0.04361809), ('n03347037', 'fire_screen', 0.034469116)]

# %% [markdown]
# ## 3. OpenCV (10 p.)

# %% [markdown]
# ### 3.1. Face Detection (3 p.)
# Use the algorithm of face detection in the given image (see the attachment).

# %%
import cv2 as cv

# %%
# 1. read the image
img  = cv.imread('attachments/3.1/image.jpg')

# 2. make the image gray
gray = cv .cvtColor(img, cv.COLOR_BGR2GRAY)

# 3. read the classifier
haar = cv.CascadeClassifier('haar.xml')

# 4. face recognition
recogn_faces = haar.detectMultiScale(gray)

# 5. how many faces recognized?
print(f"Число найденных лиц на изображении = {len(recogn_faces)}")
# Out:
# Число найденных лиц на изображении = 7

# %%
# 6. drawing the rectangle
for (x, y, w, h) in recogn_faces:
    cv.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), thickness = 2)

    
# 7. showing the image  
cv.imshow('Detected Faces', img)
   
cv.waitKey(0)

cv.destroyAllWindows()

# %% [markdown]
# ### 3.2. Face Recognition (7 p.)

# %% [markdown]
# ##### 3.2.1. Training the model (4 p).
# See the attachment with train images of faces to train the model.

# %%
import cv2 as cv
import os
import numpy as np
import cv2

# %%
people = ['johnson', 'trump']

# direction to the folder with images
DIR = r'attachments\3.2\train'

haar = cv.CascadeClassifier('haar.xml')

features = []
labels = []

def create_train():
    for person in people:
        path = os.path.join(DIR, person)
        label = people.index(person)

        for img in os.listdir(path):
            img_path = os.path.join(path, img)

            img_array = cv.imread(img_path)
            gray = cv.cvtColor(img_array, cv.COLOR_BGR2GRAY)

            faces_rect = haar.detectMultiScale(gray)

            for (x, y, w, h) in faces_rect:
                faces_roi = gray[y:y+h, x:x+w]
                features.append(faces_roi)
                labels.append(label)

# %%
create_train()

print('НАТРЕНИРОВАНО! ---------------')

features = np.array(features, dtype='object')
labels = np.array(labels)

face_recognizer = cv.face.LBPHFaceRecognizer_create()

# Train the Recognizer on the features list and the labels list
face_recognizer.train(features,labels)

face_recognizer.save('face_trained.yml')
np.save('features.npy', features)
np.save('labels.npy', labels)

# %% [markdown]
# ##### 3.2.2. Face Recognition (3 p).
# Try to recognize the images in the test folder.

# %%
haar_cascade = cv.CascadeClassifier('haar.xml')

people = ['johnson', 'trump']
# features = np.load('features.npy', allow_pickle=True)
# labels = np.load('labels.npy')

face_recognizer = cv.face.LBPHFaceRecognizer_create()
face_recognizer.read('face_trained.yml')

img = cv.imread(r'attachments\3.2\test/1.jpg')

gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)



# Detect the face in the image
faces_rect = haar_cascade.detectMultiScale(gray)

for (x,y,w,h) in faces_rect:
    faces_roi = gray[y:y+h,x:x+w]

    label, confidence = face_recognizer.predict(faces_roi)
    print(f'Label = {people[label]} with a confidence of {confidence}')

    cv.putText(img, str(people[label]), (20,20), cv.FONT_HERSHEY_COMPLEX, 1.0, (0,255,0), thickness=2)
    cv.rectangle(img, (x,y), (x+w,y+h), (0,255,0), thickness=2)

cv.imshow('Detected Face', img)

cv.waitKey(0)

cv.destroyAllWindows()

# %%
haar_cascade = cv.CascadeClassifier('haar.xml')

people = ['johnson', 'trump']
# features = np.load('features.npy', allow_pickle=True)
# labels = np.load('labels.npy')

face_recognizer = cv.face.LBPHFaceRecognizer_create()
face_recognizer.read('face_trained.yml')

img = cv.imread(r'attachments\3.2\test/2.jpg')

gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)



# Detect the face in the image
faces_rect = haar_cascade.detectMultiScale(gray)

for (x,y,w,h) in faces_rect:
    faces_roi = gray[y:y+h,x:x+w]

    label, confidence = face_recognizer.predict(faces_roi)
    print(f'Label = {people[label]} with a confidence of {confidence}')

    cv.putText(img, str(people[label]), (20,20), cv.FONT_HERSHEY_COMPLEX, 1.0, (0,255,0), thickness=2)
    cv.rectangle(img, (x,y), (x+w,y+h), (0,255,0), thickness=2)

cv.imshow('Detected Face', img)

cv.waitKey(0)

cv.destroyAllWindows()
